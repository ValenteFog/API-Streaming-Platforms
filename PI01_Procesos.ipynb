# %% [markdown]
# # API for Streaming Platforms### Importación de librerías a utilizar

# %%
# Importamos pandas para manipular el dataset
import pandas as pd

# Importamos Path para trabajar con las rutas de los archivos
from pathlib import Path

# %% [markdown]
# ### Ingesta de los Datasets
# Vemos que tenemos archivos en formato csv y json. Definimos una función para realizar la ingesta de ambos

# %%
# Ingestamos los archivos
def import_files(path):
    with open(path, 'rb'):
        if Path(path).suffix == ".csv": 
            data = pd.read_csv(path)
        elif Path(path).suffix == ".json": 
            data = pd.read_json(path, precise_float=True)
        
    return data

# %% [markdown]
# Importamos los datasets utilizando la función anterior

# %%
amazon = import_files(f'./Datasets/amazon_prime_titles.csv')
disney = import_files(f'./Datasets/disney_plus_titles.csv')
hulu = import_files(f'./Datasets/hulu_titles.csv')
netflix = import_files(f'./Datasets/netflix_titles.json')

# %% [markdown]
# ### Análisis Exploratorio de Datos (EDA)
# Comenzamos a hacer un análisis de los dataframes creados. A cada uno le vamos a dar una mirada general para descubrir sus estructuras, tipos de datos, cantidad de registros, etc. Es el primer acercamiento con los datos que hasta el momento desconocemos.

# %%
# Visualizamos el dataframe usando '.sample()' para poder ver una muestra aleatoria de los items, 
# y de esta forma tener una primera idea de cómo está conformada cada tabla. Lo hacemos para los 4 dataframes.

#amazon.sample(n=20)
#disney.sample(n=20)
#hulu.sample(n=20)
netflix.sample(15)
# Out:
#      show_id     type                                  title  \
# 5871   s5872  TV Show                           Chelsea Does
# 3167   s3168    Movie                     Celebrity Marriage
# 5128   s5129  TV Show                           Dawai Asmara
# 327     s328    Movie                                Beowulf
# 4398   s4399    Movie  Loudon Wainwright III: Surviving Twin
# 3580   s3581    Movie         Invader Zim: Enter the Florpus
# 3582   s3583    Movie                               Selfless
# 5835   s5836    Movie                Jim Jefferies: Freedumb
# 1173   s1174  TV Show                       Men on a Mission
# 8743   s8744    Movie                               Wildlife
# 2806   s2807    Movie            Bert Kreischer: Hey Big Boy
# 7786   s7787  TV Show               Power Rangers: Megaforce
# 1039   s1040    Movie             Dark City Beneath the Beat
# 6969   s6970  TV Show                      Highway Thru Hell
# 3995   s3996    Movie     Alexis Viera: A Story of Surviving
#
#                director                                               cast  \
# 5871               None                                    Chelsea Handler
# 3167      Pascal Amanfo  Kanayo O. Kanayo, Tonto Dikeh, Jackie Appiah, ...
# 5128               None  Hanna Aqiela, Tengku Putri Najuwa, Emelie Hani...
# 327     Robert Zemeckis  Ray Winstone, Anthony Hopkins, John Malkovich,...
# 4398  Christopher Guest                              Loudon Wainwright III
# 3580               None  Richard Steven Horvitz, Rikki Simons, Andy Ber...
# 3582       Tarsem Singh  Ryan Reynolds, Natalie Martinez, Matthew Goode...
# 5835        Ryan Polito                                      Jim Jefferies
# 1173         Jung-ah Im  Ho-dong Kang, Soo-geun Lee, Sang-min Lee, Youn...
# 8743          Paul Dano  Carey Mulligan, Ed Oxenbould, Bill Camp, Jake ...
# 2806        Jeff Tomsic                                     Bert Kreischer
# 7786               None  Andrew M. Gray, Ciara Hanna, John Mark Louderm...
# 1039      TT The Artist       Uneek, Mighty Mark, Tsu Terry, TT The Artist
# 6969               None  Dave Pettitt, Jamie Davis, Adam Gazzola, Kevin...
# 3995           Luis Ara                                       Alexis Viera
#
#                             country         date_added  release_year rating  \
# 5871                  United States   January 23, 2016          2016  TV-MA
# 3167                           None   December 6, 2019          2017  TV-14
# 5128                           None  December 11, 2017          2016  TV-14
# 327   United States, United Kingdom     August 1, 2021          2007  PG-13
# 4398                           None  November 13, 2018          2018  TV-14
# 3580     South Korea, United States    August 16, 2019          2019  TV-Y7
# 3582                  United States    August 16, 2019          2015  PG-13
# 5835                  United States       July 1, 2016          2016  TV-MA
# 1173                    South Korea     March 23, 2021          2021  TV-14
# 8743                  United States  September 1, 2020          2018  PG-13
# 2806                  United States     March 17, 2020          2020  TV-MA
# 7786                  United States    January 1, 2016          2013  TV-Y7
# 1039                  United States     April 15, 2021          2020  TV-MA
# 6969                         Canada   December 3, 2019          2016  TV-PG
# 3995                        Uruguay     March 20, 2019          2019  TV-MA
#
#        duration                                          listed_in  \
# 5871   1 Season                    Docuseries, Science & Nature TV
# 3167    107 min                       Dramas, International Movies
# 5128   1 Season                  International TV Shows, TV Dramas
# 327     114 min               Action & Adventure, Sci-Fi & Fantasy
# 4398     92 min                                   Music & Musicals
# 3580     72 min  Children & Family Movies, Comedies, Sci-Fi & F...
# 3582    117 min                        Sci-Fi & Fantasy, Thrillers
# 5835     87 min                                    Stand-Up Comedy
# 1173  6 Seasons  International TV Shows, Korean TV Shows, Stand...
# 8743    105 min                         Dramas, Independent Movies
# 2806     62 min                                    Stand-Up Comedy
# 7786   1 Season                                           Kids' TV
# 1039     65 min                    Documentaries, Music & Musicals
# 6969  3 Seasons                                         Reality TV
# 3995     69 min  Documentaries, International Movies, Sports Mo...
#
#                                             description
# 5871  In a provocative documentary series, comedian ...
# 3167  A successful actress with an abusive husband c...
# 5128  Following life-changing traumas, two girls fro...
# 327   This deftly animated take on a legendary Old E...
# 4398  Grammy-winning singer Loudon Wainwright III re...
# 3580  When Zim reappears to begin the next phase of ...
# 3582  A dying tycoon has his consciousness transplan...
# 5835  Returning for a second Netflix comedy special,...
# 1173  Male celebs play make-believe as high schooler...
# 8743  A teen’s life in 1960 Montana grows complicate...
# 2806  Ever the stand-up party animal, comic Bert Kre...
# 7786  When Earth is threatened by a massive alien in...
# 1039  In this documentary, TT the Artist captures th...
# 6969  On the hazardous highways of Canada's interior...
# 3995  After being shot during a robbery in Colombia ...

# %%
# Vemos la información de todas las columnas, también para los 4 dataframes

#amazon.info()
#disney.info()
#hulu.info()
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %% [markdown]
# Eliminaremos las columnas que, teniendo en cuenta las consignas planteadas, no nos serán de utilidad. Lo hacemos solo a efectos de tener una mejor visual de las tablas y de no ocupar recursos innecesarios, pero dajarlas tampoco implicaría un problema.

# %%
# Primero agregamos cada plataforma a una lista
plataformas = [amazon, disney, hulu, netflix]

# %%
# Eliminamos las columnas indeseadas
for p in plataformas:
    p.drop(columns=['director','country','date_added','rating','description'], inplace=True)

# %% [markdown]
# Modificamos la columna show_id y agregamos una columna con el nombre de la plataforma

# %%
# Reemplazamos los caracteres de la columna 'show_id' por otro más representativo a la plataforma en cuestión.
# Seteamos esta misma columna como index.
ind = ['a', 'd', 'h', 'n']
for p, i in zip(plataformas, ind):
    p['show_id'] = p['show_id'].str.replace('[a-zA-Z]', i, regex=True)
    p.set_index('show_id', inplace=True)

# %%
# Agregamos la columna plataforma
amazon['plataforma'] = 'amazon'
disney['plataforma'] = 'disney'
hulu['plataforma'] = 'hulu'
netflix['plataforma'] = 'netflix'

# %%
# Chequeamos si hay filas duplicadas
for p in plataformas:
    dup = p.duplicated().sum()
    print(f'La plataforma {p.plataforma[0]} tiene {dup} duplicados')
# Out:
# La plataforma amazon tiene 0 duplicados
# La plataforma disney tiene 0 duplicados
# La plataforma hulu tiene 0 duplicados
# La plataforma netflix tiene 0 duplicados

# %%
amazon.sample(15)
# Out:
#             type                                             title  \
# show_id
# a9565      Movie  A-Team: Life After Film School with Joe Carnahan
# a8451      Movie                                  After Miss Julie
# a882       Movie                   Storytime with Mila and Morphle
# a5162      Movie                            I Am Not Madame Bovary
# a6454      Movie                                           Painter
# a8516      Movie                                         Gang Warz
# a7437      Movie                                        Thagaraaru
# a2770    TV Show            Craig Ferguson Presents: Hobo Fabulous
# a6101      Movie                                             Awake
# a2530    TV Show                               Expedition Overland
# a2028      Movie                           Jim Gaffigan: Noble Ape
# a341       Movie                                            Ticker
# a1640      Movie                              MOM BEHIND THE WHEEL
# a388       Movie              The Woman in Black 2: Angel of Death
# a5839      Movie                                  The Funeral Home
#
#                                                       cast  release_year  \
# show_id
# a9565                                                  NaN          2010
# a8451      Geraldine Somerville, Phil Daniels, Kathy Burke          1995
# a882                                          Sabrina Glow          2019
# a5162                         Fan Bingbing, Chengpeng Dong          2016
# a6454             Betsy Randle, Eric Ladin, Casey Deidrick          2020
# a8516                  Derek Barbosa, Coolio, Reni Santoni          2004
# a7437                Arulnithi, Poorna, Jayaprakash, Pawan          2013
# a2770    Craig Ferguson, Joe Bolter, Tomas Zakopal, Ron...          2019
# a6101    Hayden Christensen, Jessica Alba, Terrence Howard          2007
# a2530    Clay Croft, Rachelle Croft, Jeff Downer, Kurt ...          2018
# a2028                                         Jim Gaffigan          2018
# a341            Tom Sizemore, Dennis Hopper, Steven Seagal          2001
# a1640    Maleja Restrepo, Tatán Mejía, Biassini Segura,...          2019
# a388     Helen McCory, Jeremy Irvine, Phoebe Fox, Ameli...          2015
# a5839    Luis Machín, Celeste Gerez, Camila Vaccarini, ...          2021
#
#           duration                                          listed_in  \
# show_id
# a9565       10 min                          Action, Adventure, Comedy
# a8451       78 min  Arts, Entertainment, and Culture, Drama, Young...
# a882        38 min                                    Animation, Kids
# a5162      139 min                                      Comedy, Drama
# a6454      100 min                                    Drama, Suspense
# a8516       97 min                                              Drama
# a7437      128 min                            Action, Drama, Suspense
# a2770     1 Season                                           TV Shows
# a6101       84 min                                    Drama, Suspense
# a2530    3 Seasons           Adventure, Documentary, Special Interest
# a2028       68 min  Arts, Entertainment, and Culture, Comedy, Spec...
# a341        92 min                        Action, Adventure, Suspense
# a1640       88 min                                             Comedy
# a388        99 min                                   Horror, Suspense
# a5839       86 min                                             Horror
#
#         plataforma
# show_id
# a9565       amazon
# a8451       amazon
# a882        amazon
# a5162       amazon
# a6454       amazon
# a8516       amazon
# a7437       amazon
# a2770       amazon
# a6101       amazon
# a2530       amazon
# a2028       amazon
# a341        amazon
# a1640       amazon
# a388        amazon
# a5839       amazon

# %% [markdown]
# ### Exploración de datos en columnas
# Ahora haremos un barrido de cada columna para determinar si encontramos datos extraños, o faltantes que deberían tenerse en cuenta.
#
# El siguiente código busca valores únicos en las columnas especificadas. No tenemos todas en cuenta ya que sabemos que las que excluímos tienen demasiados datos únicos y sería irrelevante hacer este proceso. La idea es ver si hay algún dato extraño.
# ``` python
# for p in plataformas:
#     column = ['type', 'release_year', 'duration']
#     for c in column:
#         un = p[c].unique()
#         un.sort()
#         print(f'La plataforma {p.plataforma[0]} en la columna {c} tiene los siguientes datos únicos: \n {un}')
# ```

# %%
# Código comentado para que no ensucie visualmente el notebook
'''
for p in plataformas:
    column = ['type', 'release_year', 'duration']
    for c in column:
        un = p[c].unique()
        un.sort()
        print(f'La plataforma {p.plataforma[0]} en la columna {c} tiene los siguientes datos únicos: \n {un}')
'''
# Out:
# "\nfor p in plataformas:\n    column = ['type', 'release_year', 'duration']\n    for c in column:\n        un = p[c].unique()\n        un.sort()\n        print(f'La plataforma {p.plataforma[0]} en la columna {c} tiene los siguientes datos únicos: \n {un}')\n"

# %% [markdown]
# Para las columnas 'type' y 'release_year' parece no haber nada que tocar.
#
# Por otro lado, encontramos que la columna 'duration' tiene valores nulos en los df de hulu y netflix.
#
# También que para el caso de los 'TV Show', la duración de una temporada aparece como '1 Season', mientras que para más temporadas es "Seasons". Debemos normalizar para no tener problemas luego con las querys.
#
# Adicionalmente, nos va a resultar conveniente separar los valores 'int' de los valores 'str' en 'duration'.

# %%
# Separamos valores 'int' de valores 'str' en dos columnas, y eliminamos la original
for p in plataformas:
    spt = p['duration'].str.split(' ', n=1, expand=True)
    p['duration_len'] = spt[0]
    p['duration_type'] = spt[1]
    p.drop(columns=['duration'], inplace=True)

# %%
# Reemplazamos 'Seasons' por 'Season'
for p in plataformas:
    p['duration_type'] = p['duration_type'].str.replace('Seasons', 'season')

# %% [markdown]
# Chequeamos si los nulos corresponden a 'Movie' o 'TV Show', ya que dependiendo de esto se le puede dar diferente tratamiento

# %%
# Le damos una mirada a nuestros valores nulos filtrados por type
movie_nulls = hulu[(hulu['type'] == 'Movie') & hulu['duration_len'].isnull()]
#tvshow_nulls = hulu[(hulu['type'] == 'TV Show') & hulu['duration_len'].isnull()]
#movie_nulls = netflix[(netflix['type'] == 'Movie') & netflix['duration_len'].isnull()]
#tvshow_nulls = netflix[(netflix['type'] == 'TV Show') & netflix['duration_len'].isnull()]

movie_nulls
#tvshow_nulls
# Out:
#           type                                              title  cast  \
# show_id
# h1       Movie                     Ricky Velez: Here's Everything   NaN
# h13      Movie  Out of the Shadows: The Man Behind the Steele ...   NaN
# h16      Movie  Showtime Championship Boxing: Lopez vs. Salido...   NaN
# h38      Movie                  BELLATOR MMA: Kongo vs. Johnson 2   NaN
# h41      Movie                                      In the Crease   NaN
# ...        ...                                                ...   ...
# h2952    Movie                                  All Saints (1998)   NaN
# h2956    Movie                                         Getting On   NaN
# h2959    Movie                                 (Sub) Ninja Scroll   NaN
# h2960    Movie                              Packed to the Rafters   NaN
# h2994    Movie                     Amy Winehouse: A Final Goodbye   NaN
#
#          release_year                           listed_in plataforma  \
# show_id
# h1               2021                    Comedy, Stand Up       hulu
# h13              2021                                News       hulu
# h16              2011                              Sports       hulu
# h38              2020                              Sports       hulu
# h41              2020                              Sports       hulu
# ...               ...                                 ...        ...
# h2952            1998                Drama, International       hulu
# h2956            2009       Comedy, International, Sitcom       hulu
# h2959            1993  Action, Adult Animation, Adventure       hulu
# h2960            2008        Comedy, Drama, International       hulu
# h2994            2011                Documentaries, Music       hulu
#
#         duration_len duration_type
# show_id
# h1               NaN           NaN
# h13              NaN           NaN
# h16              NaN           NaN
# h38              NaN           NaN
# h41              NaN           NaN
# ...              ...           ...
# h2952            NaN           NaN
# h2956            NaN           NaN
# h2959            NaN           NaN
# h2960            NaN           NaN
# h2994            NaN           NaN
#
# [479 rows x 8 columns]

# %% [markdown]
# Antes de darle un valor a los registros nulos, veremos si faltan datos en otras columnas. De esta forma ahorramos código posteriormente.

# %%
# Chequeamos por valores faltantes
for p in plataformas:
    column = ['type', 'title', 'cast', 'release_year', 'listed_in', 'duration_len', 'duration_type']
    for c in column:
        un = p[c].isnull().sum()
        print(f'La plataforma {p.plataforma[0]} en la columna {c} tiene {un} datos faltantes')
# Out:
# La plataforma amazon en la columna type tiene 0 datos faltantes
# La plataforma amazon en la columna title tiene 0 datos faltantes
# La plataforma amazon en la columna cast tiene 1233 datos faltantes
# La plataforma amazon en la columna release_year tiene 0 datos faltantes
# La plataforma amazon en la columna listed_in tiene 0 datos faltantes
# La plataforma amazon en la columna duration_len tiene 0 datos faltantes
# La plataforma amazon en la columna duration_type tiene 0 datos faltantes
# La plataforma disney en la columna type tiene 0 datos faltantes
# La plataforma disney en la columna title tiene 0 datos faltantes
# La plataforma disney en la columna cast tiene 190 datos faltantes
# La plataforma disney en la columna release_year tiene 0 datos faltantes
# La plataforma disney en la columna listed_in tiene 0 datos faltantes
# La plataforma disney en la columna duration_len tiene 0 datos faltantes
# La plataforma disney en la columna duration_type tiene 0 datos faltantes
# La plataforma hulu en la columna type tiene 0 datos faltantes
# La plataforma hulu en la columna title tiene 0 datos faltantes
# La plataforma hulu en la columna cast tiene 3073 datos faltantes
# La plataforma hulu en la columna release_year tiene 0 datos faltantes
# La plataforma hulu en la columna listed_in tiene 0 datos faltantes
# La plataforma hulu en la columna duration_len tiene 479 datos faltantes
# La plataforma hulu en la columna duration_type tiene 479 datos faltantes
# La plataforma netflix en la columna type tiene 0 datos faltantes
# La plataforma netflix en la columna title tiene 0 datos faltantes
# La plataforma netflix en la columna cast tiene 825 datos faltantes
# La plataforma netflix en la columna release_year tiene 0 datos faltantes
# La plataforma netflix en la columna listed_in tiene 0 datos faltantes
# La plataforma netflix en la columna duration_len tiene 3 datos faltantes
# La plataforma netflix en la columna duration_type tiene 3 datos faltantes

# %% [markdown]
# Ahora debemos darle tratamiento a todos los registros faltantes:
#         * Para las columnas de 'duration_len' y 'duration_type': Como todos los valores nulos corresponden a 'Movie', le damos el valor de 0 (cero) a 'duration_len'. Se le asigna cero para que todos los valores de la columna sean númericos. Y le damos el valor de 'min' a 'duration_type'.
#         * Para la columna cast, que tiene faltantes en todos los df, le asignamos el valor 'sin datos'.

# %%
# Llenamos los vacíos
for p in plataformas:
    p['duration_len'] = p['duration_len'].fillna(0).astype('int64')
    p['duration_type'] = p['duration_type'].fillna('min')
    p['cast'] = p['cast'].fillna('sin datos')

# %% [markdown]
# Concatenación de Dataframes y exportación en csv

# %%
# Concatenamos los 4 dataframes
plataforma_db = pd.concat(plataformas)

# %%
# Chequeamos cómo quedó el df final
plataforma_db.sample(20)
# Out:
#             type                                title  \
# show_id
# n5503      Movie                In the Shadow of Iris
# a2727      Movie                  Dangerous Obsession
# a5375      Movie                                 Gang
# n7287      Movie                               Legion
# n3093    TV Show       Kevin Hart: Don’t F**k This Up
# a4718    TV Show                                Roger
# n809       Movie                       Sniper: Legacy
# a8198      Movie                           Mr. Church
# n4984      Movie  Jag älskar dig: En skilsmässokomedi
# a8092      Movie                           Santa Who?
# a8102      Movie                       Population 436
# n6418      Movie  Capital in the Twenty-First Century
# d1356      Movie                             The Wild
# n6804    TV Show                   Friday Night Tykes
# a5744    TV Show                           Mcgraw Ave
# n5958      Movie                 To and From New York
# n7893    TV Show                   Roonpi Secret Love
# a8790      Movie                             Far More
# n3589    TV Show                       Cannon Busters
# n5270      Movie                 Barbie Dolphin Magic
#
#                                                       cast  release_year  \
# show_id
# n5503    Romain Duris, Charlotte Le Bon, Jalil Lespert,...          2016
# a2727    Janet Williams, Jay Deep, Simeon Henderson, Ja...          2014
# a5375                 Cha Ji-hyuk, Jo Sun-ki, Ock Yun-jung          2020
# n7287    Paul Bettany, Lucas Black, Tyrese Gibson, Adri...          2010
# n3093                                            sin datos          2019
# a4718                                            sin datos          2018
# n809     Tom Berenger, Chad Michael Collins, Doug Allen...          2014
# a8198    Eddie Murphy, Britt Robertson, Natascha McElho...          2016
# n4984    Björn Kjellman, Christine Meltzer, Rodolfo Cor...          2016
# a8092    Leslie Nielsen, Robyn Lively, Steven Eckholdt,...          2000
# a8102    Jeremy Sisto, Charlotte Sullivan, Peter Outerb...          2006
# n6418                                            sin datos          2019
# d1356    Kiefer Sutherland, Jim Belushi, Eddie Izzard, ...          2006
# n6804                                            sin datos          2017
# a5744    Murda Pain, Thomas L. Harris, Sino Harris, Lan...          2020
# n5958    Barbara King, Shaana Diya, John Krisiukenas, Y...          2006
# n7893                  Kanyawee Songmuang, Korapat Kirdpan          2016
# a8790    Andrian Grenier, Selma Blair, Joshua Rush, Bai...          2021
# n3589    Yoshitsugu Matsuoka, Hinaki Yano, Shiori Izawa...          2019
# n5270    Erica Lindbeck, Shannon Chan-Kent, Kazumi Evan...          2017
#
#                                                  listed_in plataforma  \
# show_id
# n5503              Dramas, International Movies, Thrillers    netflix
# a2727                                             Suspense     amazon
# a5375                                       Action, Comedy     amazon
# n7287    Action & Adventure, Horror Movies, Sci-Fi & Fa...    netflix
# n3093                                           Docuseries    netflix
# a4718                                      Animation, Kids     amazon
# n809                                    Action & Adventure    netflix
# a8198                                        Comedy, Drama     amazon
# n4984               Comedies, Dramas, International Movies    netflix
# a8092                                               Comedy     amazon
# a8102                                     Horror, Suspense     amazon
# n6418                                        Documentaries    netflix
# d1356                  Action-Adventure, Animation, Comedy     disney
# n6804                               Docuseries, Reality TV    netflix
# a5744                                        Action, Drama     amazon
# n5958                Dramas, Independent Movies, Thrillers    netflix
# n7893    International TV Shows, Romantic TV Shows, Tee...    netflix
# a8790                                        Comedy, Drama     amazon
# n3589                 Anime Series, International TV Shows    netflix
# n5270                             Children & Family Movies    netflix
#
#          duration_len duration_type
# show_id
# n5503              99           min
# a2727              78           min
# a5375              94           min
# n7287             100           min
# n3093               1        Season
# a4718               1        Season
# n809               98           min
# a8198             105           min
# n4984              91           min
# a8092              92           min
# a8102              92           min
# n6418             103           min
# d1356              86           min
# n6804               4        season
# a5744               1        Season
# n5958              81           min
# n7893               3        season
# a8790              98           min
# n3589               1        Season
# n5270              64           min

# %%
# Exportamos a un archivo csv
plataforma_db.to_csv(r'./Datasets/plataforma_db.csv')

# %% [markdown]
# # Consultas
# A continuación definiremos las funciones para realizar las posteriores consultas a la API

# %%
# Máxima duración según tipo de film (película/serie), por plataforma y por año: El request debe ser: get_max_duration(año, plataforma, [min o season])
def get_max_duration(anio, plataforma, duracion):
    plataforma = plataforma.lower().strip()
    duracion = duracion.lower().strip()
    db = pd.read_csv(r'./Datasets/plataforma_db.csv')
    query_1 = db[(db['plataforma'] == plataforma) & (db['release_year'] == anio) & (db['duration_type'] == duracion)]
    out = query_1.sort_values('duration_len', ascending=False, ignore_index=True)
    return (f'La producción "{out.title[0]}", con {out.duration_len[0]} {duracion}, fue la de mayor duración en la plataforma {plataforma}')

# %%
get_max_duration(2018,'hulu','min')
# Out:
# 'La producción "The House That Jack Built", con 151 min, fue la de mayor duración en la plataforma hulu'

# %%
# Cantidad de películas y series (separado) por plataforma El request debe ser: get_count_plataform(plataforma)
def get_count_plataform(plataforma):
    plataforma = plataforma.lower().strip()
    db = pd.read_csv(r'./Datasets/plataforma_db.csv')
    query_2 = db[db['plataforma'] == plataforma]
    cant = query_2['type'].value_counts()
    return (f'En la plataforma {plataforma} hay un total de {cant[0]} películas y de {cant[1]} series')

# %%
get_count_plataform('netflix')
# Out:
# 'En la plataforma netflix hay un total de 6131 películas y de 2676 series'

# %%
# Cantidad de veces que se repite un género y plataforma con mayor frecuencia del mismo. El request debe ser: get_listedin('genero')
# Como ejemplo de género pueden usar 'comedy', el cuál deberia devolverles un cunt de 2099 para la plataforma de amazon.
def get_listedin(genero):
    genero = genero.lower().strip()
    db = pd.read_csv(r'./Datasets/plataforma_db.csv')
    query_3 = db[db['listed_in'].str.contains(genero, case=False)]
    query_3 = query_3.groupby(['plataforma'])['plataforma'].count().sort_values(ascending=False)
    query_3 = query_3.to_dict()

    return (f'El genero "{genero}" se repite {list(query_3.values())[0]} veces para la plataforma {list(query_3)[0]}')

# %%
get_listedin('comedy')
# Out:
# 'El genero "comedy" se repite 2099 veces para la plataforma amazon'

# %%
# Actor que más se repite según plataforma y año. El request debe ser: get_actor(plataforma, año)
def get_actor(plataforma, anio):
    plataforma = plataforma.lower().strip()
    db = pd.read_csv(r'./Datasets/plataforma_db.csv')
    db.drop(db[db['cast'] == 'sin datos'].index, inplace = True)
    query_4 = db.query(f'plataforma == "{plataforma}" & release_year == {anio}')
    cant = query_4['cast'].str.get_dummies(sep=', ').sum()
    cant = cant.sort_values(ascending=False).to_dict()
    
    return (f'El actor "{list(cant)[0]}" se repite {list(cant.values())[0]} veces para la plataforma {plataforma} en el año {anio}')

# %%
get_actor('netflix', 2018)
# Out:
# 'El actor "Andrea Libman" se repite 8 veces para la plataforma netflix en el año 2018'
